# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import LocalOutlierFactor
from mlxtend.frequent_patterns import apriori, association_rules
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,confusion_matrix, classification_report, ConfusionMatrixDisplay, silhouette_score,roc_curve, auc

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# <h1>Feature Engineering</h1>

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df = df.fillna(0)

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# %%
categorical_cols
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=False, cmap="coolwarm")
plt.title("Mapa de Calor das Correlações")
plt.show()

# %%
corr_target = corr['SalePrice'].sort_values(ascending=False)
print(corr_target)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.472614
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# GarageYrBlt      0.261366
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# LotFrontage      0.209624
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %% [markdown]
# <h1>Aprendizagem Supervisionada - Regressão Linear</h1>

# %%
features = [ 'OverallQual', 'GrLivArea', 'GarageCars', 
    'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 
    'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd']

# %%
X = df[features]
Y = df['SalePrice']

# %%
X_train, X_test, Y_train,Y_test = train_test_split(X,Y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f'MSE: {mse:.2f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAE: {mae:.2f}')
print(f'R²: {r2:.2f}')
# Out:
# MSE: 1387787630.82
# RMSE: 37253.02
# MAE: 24355.87
# R²: 0.80

# %%
plt.scatter(Y_test, Y_pred)
plt.xlabel('Valores Reais')
plt.ylabel('Valores Preditos')
plt.title('Valores Reais vs. Preditos')
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--')
plt.show()

# %%
coeficientes = pd.DataFrame({
    'Atributo': X.columns,
    'Coeficiente': model.coef_
}).sort_values(by='Coeficiente', ascending=False)

print(coeficientes)
# Out:
#        Atributo   Coeficiente
# 0   OverallQual  19706.155920
# 2    GarageCars  14181.862962
# 7  TotRmsAbvGrd    594.193773
# 9  YearRemodAdd    304.456332
# 8     YearBuilt    289.106875
# 1     GrLivArea     46.415115
# 5      1stFlrSF     15.303836
# 4   TotalBsmtSF     12.057829
# 3    GarageArea      7.521263
# 6      FullBath  -6968.063288

# %% [markdown]
# <h1>Aprendizagem Supervisionada - Classificação Random Forest</h1>

# %%
threshold = df['SalePrice'].median()

df['HighPrice'] = (df['SalePrice']>threshold).astype(int)

print(df['HighPrice'].value_counts())
# Out:
# HighPrice
# 0    732
# 1    728
# Name: count, dtype: int64

# %%
X = df[features]
Y = df['HighPrice']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.3, random_state=42)

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93       233
#            1       0.89      0.95      0.92       205
#
#     accuracy                           0.92       438
#    macro avg       0.92      0.92      0.92       438
# weighted avg       0.92      0.92      0.92       438

# %%
importances = rf_model.feature_importances_
features = X.columns
feat_importances = pd.Series(importances, index=features)
plt.figure(figsize=(8,6))
feat_importances.nlargest(10).plot(kind='barh', color='forestgreen')
plt.title('Importância das Variáveis - Random Forest')
plt.xlabel('Importância')
plt.ylabel('Variáveis')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred_rf)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

plt.figure(figsize=(6,6))
disp.plot(cmap=plt.cm.Greens, colorbar=False)
plt.title('Matriz de Confusão - Random Forest')
plt.show()

# %%
y_prob = rf_model.predict_proba(X_test)[:,1]


fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)


plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (área = {roc_auc:.2f})')
plt.plot([0,1], [0,1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('Taxa de Falso Positivo')
plt.ylabel('Taxa de Verdadeiro Positivo')
plt.title('Curva ROC - Random Forest')
plt.legend(loc="lower right")
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# <h1>Aprendizagem Não Supervisionada - Clusterização</h1>

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# %%
for col in ['SalePrice', 'HighPrice']:
    if col in numeric_cols:
        numeric_cols.remove(col)

# %%
df_encoded = pd.get_dummies(df,columns=categorical_cols)
X = df_encoded

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
df['Cluster'] = kmeans.predict(X_scaled)

# %% [markdown]
# <h1>Aprendizagem Não Supervisionada - Redução de Dimensionalidade</h1>

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
df_plot = pd.DataFrame({
    'PCA1': X_pca[:, 0],
    'PCA2': X_pca[:, 1],
    'Cluster': kmeans.labels_
})

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=df_plot, x='PCA1', y='PCA2',
    hue='Cluster', palette='Set1', s=60
)
plt.title('Visualização dos Clusters com PCA')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.legend(title='Cluster')
plt.show()

# %% [markdown]
# <h1>Aprendizagem Não Supervisionada - Metodo Apriori</h1>

# %%
selected_columns = [col for col in df_encoded.columns if
    'Neighborhood_' in col or
    'MSZoning_' in col or
    'HouseStyle_' in col or
    'SaleCondition_' in col or
    'SaleType_' in col or
    col == 'HighPrice'
]
df_apriori = df_encoded[selected_columns].astype(bool)

# %%
df_apriori.head()
# Out:
#    HighPrice  MSZoning_C (all)  MSZoning_FV  MSZoning_RH  MSZoning_RL  \
# 0       True             False        False        False         True
# 1       True             False        False        False         True
# 2       True             False        False        False         True
# 3      False             False        False        False         True
# 4       True             False        False        False         True
#
#    MSZoning_RM  Neighborhood_Blmngtn  Neighborhood_Blueste  \
# 0        False                 False                 False
# 1        False                 False                 False
# 2        False                 False                 False
# 3        False                 False                 False
# 4        False                 False                 False
#
#    Neighborhood_BrDale  Neighborhood_BrkSide  ...  SaleType_ConLw  \
# 0                False                 False  ...           False
# ...

# %%
frequent_itemsets = apriori(df_apriori, min_support=0.15, use_colnames=True)
df_rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
    df_rules['support'],
    df_rules['confidence'],
    c=df_rules['lift'],
    cmap='viridis',
    alpha=0.7,
    edgecolors='k'
)

cbar = plt.colorbar(scatter)
cbar.set_label('Lift')

plt.title('Regras de Associação - Apriori')
plt.xlabel('Suporte')
plt.ylabel('Confiança')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Aprendizagem Não Supervisionada - Outliers</h1>

# %%
X = df_encoded.drop(['SalePrice', 'HighPrice'], axis=1)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
lof = LocalOutlierFactor(n_neighbors=20, contamination=0.05)
y_pred = lof.fit_predict(X_scaled)

# %%
df['Outlier'] = y_pred

# %%
outliers = df[df['Outlier'] == -1]
print(outliers)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5        6          50       RL         85.0    14115   Pave     0      IR1
# 9       10         190       RL         50.0     7420   Pave     0      Reg
# 29      30          30       RM         60.0     6324   Pave     0      IR1
# 52      53          90       RM        110.0     8472   Grvl     0      IR2
# 120    121          80       RL          0.0    21453   Pave     0      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 1370  1371          50       RL         90.0     5400   Pave     0      Reg
# 1379  1380          80       RL         73.0     9735   Pave     0      Reg
# 1386  1387          60       RL         80.0    16692   Pave     0      IR1
# 1423  1424          80       RL          0.0    19690   Pave     0      IR1
#
# ...

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(
    X_pca[y_pred == 1, 0], X_pca[y_pred == 1, 1],
    c='blue', label='Normais', alpha=0.5
)
plt.scatter(
    X_pca[y_pred == -1, 0], X_pca[y_pred == -1, 1],
    c='red', label='Outliers', edgecolors='k', marker='x', s=80
)

plt.title('Outliers detectados com Local Outlier Factor (LOF)')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Enso\AppData\Local\Temp\ipykernel_9984\817961935.py:6: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(
